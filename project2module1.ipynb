# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Владислав, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# ### Цели и задачи проекта:
#
# С помощью датасета с информацией о клиентах и их активности, надо проанализировать и выявить портрет пользователя, который с большей вероятностью будет возвращаться на платформу и делать повторные заказы. Это поможет оптимизировать рекламные бюжеты и влиять на продолжительность удержания клиента

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Здорово, что оставляешь вводную часть! Она помогает быстро понять цель, контекст и структуру работы, что будет удобно не только для тебя при возвращении к проекту спустя время, но и любому другому читателю (если, например, публикуешь в открытый доступ для портфолио). Воспринимаем эту тетрадку не просто как выполнение домашней работы на курсе, а как полноценный исследовательский проект.
#
# Как правило, в вводную часть включают название проекта, краткое описание цели, используемых данных (источники, объем, особенности), нюансы самого проекта (специфические условия, ограничения, предположения и т.д.). Иногда также сразу обозначают план шагов. Другими словами, вводная часть призвана отразить, что мы делаем, с чем работаем и на каких условиях.
# </div>

# %% [markdown]
# ## Этапы выполнения проекта
#
# ### 1. Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные. Используйте следующие параметры для подключения к базе данных `data-analyst-afisha`:
#
# - **Хост** — `rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net`
# - **База данных** — `data-analyst-afisha`
# - **Порт** — `6432`
# - **Аутентификация** — `Database Native`
# - **Пользователь** — `praktikum_student`
# - **Пароль** — `Sdf4$2;d-d30pp`
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %%
#Установка необходимых библиотек
# !pip install sqlalchemy

# %%
# Импорт необходимым библиотек для анализа и импорта данных
import numpy as np
import pandas as pd

from sqlalchemy import create_engine

#Импорт библиотек для работы с чувствительными данными
from dotenv import load_dotenv
import os

#Импорт библиотек для визуализации
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Подгружаю данные из .env-файла
load_dotenv()
# Out:
# True

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Все необходимые библиотеки стоит выгружать в начале проекта в одной ячейке кода. Чтобы сразу видеть, какие модули используются в проекте

# %% [markdown]
# # Подключение к базе данных
# db_config = {'user': 'praktikum_student', # имя пользователя
#              'pwd': 'Sdf4$2;d-d30pp', # пароль
#              'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
#              'port': 6432, # порт подключения
#              'db': 'data-analyst-afisha' # название базы данных
#              }

# %%
#Получаю доступ к БД, используя данные из файла .env
db_config = {
    'user': os.getenv('DB_USER'),
    'pwd': os.getenv('DB_PASSWORD'),
    'host': os.getenv('DB_HOST'),
    'port': os.getenv('DB_PORT'),
    'db': os.getenv('DB_NAME')
}

# %%
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db'],
)

# %%
engine = create_engine(connection_string)

# %%
query = '''
-- Настройка параметра synchronize_seqscans важна для проверки
WITH set_config_precode AS (
  SELECT set_config('synchronize_seqscans', 'off', true)
)
-- Напишите ваш запрос ниже
SELECT p.user_id,
      p.device_type_canonical,
      p.order_id,
      p.created_dt_msk AS order_dt,
      p.created_ts_msk AS order_ts,
      p.currency_code,
      p.revenue,
      p.tickets_count,
      EXTRACT (DAY FROM (p.created_dt_msk - LAG(p.created_dt_msk) OVER (PARTITION BY p.user_id ORDER BY p.created_dt_msk)))::INTEGER AS days_since_prev,
      p.event_id,
      e.event_name_code AS event_name,
      e.event_type_main,
      p.service_name,
      r.region_name,
      c.city_name
FROM afisha.purchases p
JOIN afisha.events e USING(event_id)
JOIN afisha.city c USING(city_id)
JOIN afisha.regions r USING(region_id)
WHERE p.device_type_canonical IN ('mobile', 'desktop') AND e.event_type_main NOT IN ('фильм')
ORDER BY p.user_id;
'''

# %%
#Присваиваем SQL-запрос переменной df
df = pd.read_sql_query(query, con=engine)

# %%
#Смотрим на результат выгрузки
df.head(5)
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name event_type_main  \
# ...

# %%
#Проверяем размер датасета 
df.shape
# Out:
# (290611, 15)

# %%
#Смотрим основную информацию о датасете
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# #### Промежуточные выводы по первому шагу:
# - Данные корректно выгрузились с помощью SQL-запроса
# - Размер датасета 290611 строк и 15 колонок
# - Названия колонок приведены к одному типу
# - Пропущенные значения есть только в колонке "days_since_prev", количество пропусков 21.933 штуки
# - В предобработке можно уменьшить рамерность полей с целочисленными показателями

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# * Хорошо, что убеждаешь в корректности данных! Если при подгрузке возникли проблемы, а мы их не обнаружим, все последующие расчеты могут быть искажены.
#
#
# * Круто, что не забываешь зафиксировать промежуточные наблюдения в выводах! Если потребуется вернуться к проекту спустя время, будет проще освежить в памяти все ключевые этапы работы, что и почему мы делали, что получили.

# %% [markdown]
# ---
#
# ###  2. Предобработка данных
#
# Выполните все стандартные действия по предобработке данных:
#
# ---
#
# **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %%
#Загружаю датасет с курсом тенге к рублю
df_kzt = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')

# %%
#Пока что закомментирую свой вариант решения

# %% [markdown]
# #Создаю поле с информацией по 1 тенге, чтобы дальше было легче считать
# df_kzt['1tenge'] = df_kzt['curs'] / 100

# %% [markdown]
# #Провеяю новое поле
# df_kzt.head(3)

# %%
#Проверяю тип данных у полей
df_kzt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    object
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.3+ KB

# %%
#Преобразовываю дату чтобы легче объединить таблицы
df_kzt['data'] = pd.to_datetime(df_kzt['data'])

# %%
#Легче всего будет объединить 2 датафрейма, оставив только те даты, которые совпадают
#В левой таблице будет df (данные за 5 месяцев) и в правой df_kzt(представленны данные за весь год)
df = df.merge(df_kzt[['data', 'curs']], left_on='order_dt', right_on='data', how='left').drop('data', axis=1)

# %% [markdown]
# #Проверяю изменения
# df.head(3)

# %% [markdown]
# #Создаю копии поля с выручкой, чтобы не было NaN-значений в результатирующей таблице
# df['revenue_rub'] = df['revenue']
#
# #Создаю маску для строк с валютой тенге
# kzt_mask = df['currency_code'] == 'kzt'
#
# #Умножаю выручку на курс тенге для строк, где 'kzt' == True
# df.loc[kzt_mask, 'revenue_rub'] = df.loc[kzt_mask, 'revenue'] * df.loc[kzt_mask, '1tenge']

# %% [markdown]
# #Проверяю результат
# df[df['currency_code'] == 'kzt']

# %% [markdown]
# #Удаляю колонку, которую использовали для подсчета
# df = df.drop('1tenge', axis=1)

# %% [markdown]
# #Проверяю результат
# df.head(3)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С шагом справились, результат корректный! Хорошо, что убеждаешься в этом.
# </div>
#
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * Существует довольно удобный метод [where](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html). Мы можем применить его к столбцу и указать условие, которое будем проверять, а также альтернативный вариант значения. Если условие выполняется, то берется значение из столбца, если нет - альтернативное значение. Тогда расчет выручки в рублях будет выглядеть следующим образом:
#
#     ```python
# df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / 100)
# ```
#
#
#
# * Не забываем фиксировать в выводах наши промежуточные наблюдения (например, что все прошло хорошо, теперь выручка скорректирована, и ее можно использовать для дальнейшего анализа).
#
# </div>

# %% [markdown]
# #### Выполню эту задачу через способ с методом where

# %%
#Создаем новую колонку с помошью метода .where(условие True, то что False)
df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs']/100)

# %%
#Проверяю результат
df[df['currency_code'] == 'kzt'].head(50)
# Out:
#               user_id device_type_canonical  order_id   order_dt  \
# 70    0033403583a55ed                mobile   7850214 2024-09-17
# 89    0040e12d70fae81               desktop   8634925 2024-09-02
# 96    0054b38b2653e6e                mobile   7625522 2024-09-09
# 277   00f4f5244501ce6                mobile    720419 2024-06-11
# 460   01370a0e9c1a7d5               desktop   5227657 2024-06-04
# 461   01370a0e9c1a7d5                mobile   2229811 2024-06-04
# 462   01370a0e9c1a7d5                mobile   2229782 2024-06-04
# 463   01370a0e9c1a7d5                mobile   2229753 2024-06-04
# 464   01370a0e9c1a7d5                mobile   2229724 2024-06-04
# 515   01370a0e9c1a7d5                mobile   2044298 2024-09-05
# 516   01370a0e9c1a7d5                mobile   2044327 2024-09-05
# 707   0186f6e000b581c                mobile   6250980 2024-09-06
# 809   019fa401ddb00aa                mobile   4451269 2024-06-11
# ...

# %%
#Проверяю размер датасета после изменений
df.shape
# Out:
# (290611, 17)

# %%
#Удаляю колонку, которую мы использовали для расчетов
df = df.drop(columns = ['curs'])

# %%
#Проверяю результат
df.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name event_type_main  \
# ...

# %% [markdown]
# #### Промежуточные итоги по "Шагу 1.2(Преобразование данных)":
# - Была создана новая колонка "revenue_rub", где показана итоговая сумма в рублях. Информация облегчает расчет выручки для заказов, которые были оплачены казахским тенге

# %% [markdown]
# ---
#
# **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %% [markdown]
# #### Пропуски

# %%
#Проверяю наличие пропусков
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %%
#Подсчет пропущенных значений
df.isna().sum()
# Out:
# user_id                      0
# device_type_canonical        0
# order_id                     0
# order_dt                     0
# order_ts                     0
# currency_code                0
# revenue                      0
# tickets_count                0
# days_since_prev          21933
# event_id                     0
# event_name                   0
# event_type_main              0
# service_name                 0
# region_name                  0
# city_name                    0
# revenue_rub                  0
# dtype: int64

# %%
#Анализ колонок для лучшего понимания природы пропусков
df.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name event_type_main  \
# ...

# %% [markdown]
# <b> Анализ природы пропусков: Видим, что есть пропуски в колонке 'days_since_prev' - тут пустые значения, потому что покупатель совершил 1 заказ и соответственно разницы между повторными заказами просто нету </b>

# %% [markdown]
# #### Преобразование данных

# %%
#Получаю информацию о типах данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# <b> Видно, что есть колонки с целочисленными показателями, их размерность можно оптимизировать </b>

# %%
#Уменьшаю размерность для колонок с целочисленными значениями с помощью цикла
for column in df[['order_id', 'tickets_count', 'event_id']]:
    df[column] = pd.to_numeric(df[column], downcast='integer')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Ты молодец, что подумал про оптимизацию памяти, это полезная штука, особенно если работаешь с большими датасетами (можем получить смещение данных)

# %%
#Проверяю результат уменьшения размерности
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int32
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int8
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int32
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# #### Изучение категориальных данных с номимальными значениями

# %%
#Считаю количество дубликатов
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Считаю дубликаты в колонке order_id
df['order_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
#Изучаю категориальные поля в поисках ошибок
df['device_type_canonical'].unique()
# Out:
# array(['mobile', 'desktop'], dtype=object)

# %%
df['currency_code'].unique()
# Out:
# array(['rub', 'kzt'], dtype=object)

# %%
df['event_type_main'].unique()
# Out:
# array(['театр', 'выставки', 'другое', 'стендап', 'концерты', 'спорт',
#        'ёлки'], dtype=object)

# %%
df['event_name'].unique()
# Out:
# array(['f0f7b271-04eb-4af6-bcb8-8f05cf46d6ad',
#        '40efeb04-81b7-4135-b41f-708ff00cc64c',
#        '01f3fb7b-ed07-4f94-b1d3-9a2e1ee5a8ca', ...,
#        'cf71bf2b-8e5c-47e0-a0f3-c2d4910c4677',
#        'f17a01b7-3cd3-4cd1-919c-3459bd074886',
#        '0fd6df8e-49e5-4337-954d-5a4606b1b899'],
#       shape=(15248,), dtype=object)

# %%
#df['city_name'].unique()
df['city_name'].nunique()
# Out:
# 352

# %%
#df['city_name'].unique()
df['region_name'].nunique()
# Out:
# 81

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Тут я бы рекомендовал более тщательнее следить за чистотой данных, проверить категориальные признаки на предмет аномалий и сследить за распределением данных по признакам. Так можно сразу отловить категории с небольшим количеством данных
#
#         # Анализ категориальных значений
#         for column in ['columnname', 'columnname', 'columnname', 'columnname']:
#         print(f"\nColumn: {column}")
#         print("Unique values:", df[column].unique())
#         print("Missing values count:", df[column].isna().sum())
#         print("Value counts:")
#         print(df[column].value_counts(dropna=False), "\n")

# %%
#Смотрю какие колонки являются категориальными
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int32
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int8
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int32
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %%
#Создам список категориальных колонок
categorical_columns = ['device_type_canonical', 'currency_code', 'event_type_main', 'service_name', 'region_name', 'city_name']
    
# Анализ категориальных значений с помощью цикла for in
for column in categorical_columns:
        print(f"\nColumn: {column}")
        print("Unique values:", df[column].unique())
        print("Missing values count:", df[column].isna().sum())
        print("Value counts:")
        print(df[column].value_counts(dropna=False), "\n")
# Out:
# Column: device_type_canonical
# Unique values: ['mobile' 'desktop']
# Missing values count: 0
# Value counts:
# device_type_canonical
# mobile     232490
# desktop     58121
# Name: count, dtype: int64
#
#
# Column: currency_code
# Unique values: ['rub' 'kzt']
# Missing values count: 0
# Value counts:
# currency_code
# rub    285542
# kzt      5069
# Name: count, dtype: int64
#
#
# Column: event_type_main
# Unique values: ['театр' 'выставки' 'другое' 'стендап' 'концерты' 'спорт' 'ёлки']
# Missing values count: 0
# Value counts:
# event_type_main
# концерты    115276
# театр        67321
# другое       65867
# спорт        21911
# стендап      13393
# выставки      4854
# ёлки          1989
# Name: count, dtype: int64
#
#
# Column: service_name
# Unique values: ['Край билетов' 'Мой билет' 'За билетом!' 'Лови билет!'
#  'Билеты без проблем' 'Облачко' 'Лучшие билеты' 'Прачечная' 'Быстробилет'
#  'Дом культуры' 'Весь в билетах' 'Билеты в руки' 'Тебе билет!'
# ...

# %% [markdown]
# <b> Согласен, так в 10 раз быстрее и проще</b>

# %% [markdown]
# #### Изучение численных данных - "revenue_rub"

# %%
#Вывожу название всех колонок и их типы
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int32
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int8
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int32
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %%
#Изучею статистику по выручке
df['revenue_rub'].describe()
# Out:
# count    290611.000000
# mean        555.571987
# std         875.498172
# min         -90.760000
# 25%         113.970000
# 50%         351.140000
# 75%         802.050000
# max       81174.540000
# Name: revenue_rub, dtype: float64

# %% [markdown]
# - Большое стандартное отклонение
# - Среднее значение и медиана разняться, говорит о неравномерном распределении значений
# - Максимальное и маинимальное значение далеки от среднего (Высокая изменчивость)
# - Максимальное значение слишком далеко от среднего и медианы (скорее всего выброс)

# %%
#Создаю Boxplot для анализа размаха значений и поиска выбросов
plt.figure(figsize=(6,4))

plt.boxplot(df['revenue'], vert=False)
plt.title('Размах данных')
plt.xlabel('Выручка в рублях')
plt.grid(True)

# %% [markdown]
# Большое количество выбросов

# %%
#Создаю boxplot без учета выбросов
plt.figure(figsize=(6, 4))

plt.boxplot(df['revenue_rub'], vert=False, showfliers=False)
plt.title('Размах данных')
plt.xlabel('Выручка в рублях')
plt.grid(True)

# %%
#Создаю гистограмму, чтобы посмотреть на распределение значений в колонке "revenue_rub"

plt.figure(figsize=(6, 4))

plt.hist(df['revenue_rub'], bins=30, edgecolor='black')
#Подписываю оси графика и настраиваю отображение
plt.title('Распределение выручки')
plt.grid(True)
plt.show()

# %%
# Хочу также изучить припроду отрицательных значений в колонке
df[df['revenue_rub'] < 0].head(3)
# Out:
#               user_id device_type_canonical  order_id   order_dt  \
# 252   00eb3dc9baa1543                mobile   1594653 2024-06-29
# 4539  02ea4583333f064                mobile   2360920 2024-09-03
# 4544  02ea4583333f064                mobile   2361094 2024-09-04
#
#                 order_ts currency_code  revenue  tickets_count  \
# 252  2024-06-29 15:01:43           rub    -2.37              3
# 4539 2024-09-03 18:12:58           rub    -0.23              3
# 4544 2024-09-04 09:34:53           rub    -0.15              2
#
#       days_since_prev  event_id                            event_name  \
# 252               NaN    538650  ffe03bc6-0e0c-480d-b037-6a4b55540ab5
# 4539              0.0    559772  592856bb-09a5-4d32-9534-0e02c6056e44
# 4544              0.0    559772  592856bb-09a5-4d32-9534-0e02c6056e44
#
#      event_type_main        service_name          region_name    city_name  \
# 252           другое  Билеты без проблем  Берёзовская область  Златопольск
# ...

# %% [markdown]
# <b> Не могу определить с чем связаны отрицательные значения в колонках, возможно ошибка на стороне сервиса, избавлюсь от этих значений</b>

# %%
#Считаю количество отрицательных значений
negative_numbers = len(df[df['revenue_rub'] < 0])
negative_numbers
# Out:
# 381

# %%
#Чтобы нормально визуализировать распределение данных, избавимся от выбросов и аномальных значений
#Оставим значение ниже 99 процентиля и которые больше 0
upper_limit = df['revenue_rub'].quantile(0.99)
filtered_revenue = df[(df['revenue_rub'] < upper_limit) & (df['revenue_rub'] >= 0)]['revenue_rub']

# %%
#Визуализируем распределение с данными без выбросов
plt.hist(filtered_revenue, edgecolor='black', bins=30)

plt.grid(True)
plt.title('Распределение выручки в рублях')
plt.xlabel('Выручка от заказа')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# Правое ассиметричное распределение

# %%
#Считаем моду для отфильтронной колонки, счоты узнать какое самое популярное значение
from statistics import mode

mode_value = mode(df['revenue_rub'])
mode_value
# Out:
# 0.0

# %%
#Считаю количество строк в сходном датасете
shape = df.shape[0]
shape
# Out:
# 290611

# %%
#Считаю количиство отфильтрованных строк, которые не попали в filtered_value датафрейм
removed_rows = len(df) - len(filtered_revenue) 
removed_rows = removed_rows + negative_numbers
removed_rows
# Out:
# 3769

# %%
#Перезаписываю исходный датасет, убрав колонки с аномальными значениями
#df = df[df['revenue_rub'] <= upper_limit]
df = df[(df['revenue_rub'] <= upper_limit) & (df['revenue_rub'] >= 0)]

# %%
#Считаю размер обновленного датасета
df.shape
# Out:
# (287405, 16)

# %%
#Считаю относительную величину отфильтрованных строк
removed_rows_perc = (removed_rows / len(df)) * 100
removed_rows_perc = round(removed_rows_perc, 2)
removed_rows_perc
# Out:
# 1.31

# %% [markdown]
# #### Изучение целочисленных данных - "tickets_count"

# %%
#Смотрю стат показатели 
df['tickets_count'].describe()
# Out:
# count    287405.000000
# mean          2.741323
# std           1.163087
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %% [markdown]
# - Аномальное максимальное значение
# - Медиана и среднее знаение не сильно различается, предположительно нормальное распределение

# %%
#Создаю график размаха для колонки с купленными билетами

plt.figure(figsize=(6, 4))

plt.boxplot(df['tickets_count'], vert=False)
#Подписываю оси графика и настраиваю отображение
plt.title('Количество купленных билетов в одном заказе')
plt.grid(True)
plt.show()

# %%
#Создаю график размаха без выбросов

plt.figure(figsize=(6, 4))

plt.boxplot(df['tickets_count'], vert=False, showfliers=False)
#Подписываю оси графика и настраиваю отображение
plt.title('Количество купленных билетов в одном заказе')
plt.xlabel('Количество билетов')
plt.grid(True)
plt.show()

# %%
#Создаю гистограмму, чтобы посмотреть на распределение значений в колонке "tickets_count"

plt.figure(figsize=(6, 4))

plt.hist(df['tickets_count'], bins=30, edgecolor='black')
#Подписываю оси графика и настраиваю отображение
plt.title('Количество купленных билетов')
plt.xlabel('Количество билетов')
plt.ylabel('Количество заказов')
plt.grid(True)
plt.show()

# %% [markdown]
# Ничего не понятно из-за аномально высоких значений

# %%
#Избавляемся от выбросов
ticket_limit = df['tickets_count'].quantile(0.99)
filtered_tickets = df[df['tickets_count'] < ticket_limit]['tickets_count']

# %%
#Создаю гистограмму без выбросов
plt.figure(figsize=(6, 4))

plt.hist(filtered_tickets , bins=30, edgecolor='black')
#Подписываю оси графика и настраиваю отображение
plt.title('Количество купленных билетов')
plt.xlabel('Количество билетов')
plt.ylabel('Количество заказов')
plt.grid(True)
plt.show()

# %%
#Считаю количество отфильтрованных данных в поле "tickets_count"
removed_ticket_rows = len(df) - len(filtered_tickets)
removed_ticket_rows
# Out:
# 4124

# %%
#Удаляю аномальные значения
df = df[df['tickets_count'] <= ticket_limit]

# %%
#Проверяю размер датасета после удаления
df.shape
# Out:
# (287225, 16)

# %%
#Проверяю размер исходного датасета
shape
# Out:
# 290611

# %%
#Считаю общее количество удаленных строк
total_removed = shape - df.shape[0]
print(f"Всего было удаленно {total_removed} строк из датасета")


#Считаю относительную величину
removed_share = (total_removed / shape) * 100
print(f"Относительная величина удаленных значений составляла: {round(removed_share, 2)}% от обшего количества строк")
# Out:
# Всего было удаленно 3386 строк из датасета
# Относительная величина удаленных значений составляла: 1.17% от обшего количества строк

# %% [markdown]
# #### Промежуточные итоги по "Шагу 2(Преобразование данных)":
# - Пропуски присутствуют только в колонке "days_since_prev"
# - По моему мнению, данные соответствуют указанным типам, поэтому я не стал выполнять преобразование типов
# - Уменьшена размерность для колонок с типом данных integer
# - Дубликаты не обнаружены
# - Не выявлено ошибок в номинальных значениях категориальных колонок
# - Проанализировал распределение значений в колонках "revenue_rub" и "tickets_count"
# - Удалено 1.03% строк из датафрейма, эти строки являлись выбросами (аномальными значениями), которые сильно искажали результат исследования
#
# #### Анализ распределения "revenue_rub":
# - Большое количество выбросов, которые сильно искажают результаты анализов
# - Если смотреть на данные без учета выбросов, то видно, что меж квартильный размах лежит в диапазоне (от 113 до 802).
# - Видно, что правое ассиметричное распределение данных в датафрейме.
# - Посчитал моду для колонки с выручкой в рублях, выяснилось, что самое частое значение это 0.0. Предпологаю, что наибольшей популярностью у людей пользуются бесплатные мероприятия.
# - Можно сделать вывод, что с увеличением цены за билеты на мероприятие падает и количество людей, которые на него идут.
# - Был отфильтрован датасет, из него были убраны все значения ниже 0 и которые превышают 99 персентиль. Всего таких строк - 3769 штук
# - Решил, что могу пожертвовать таким количеством строк (чуть более 1% от общего количества), чтобы в дальнейшем получать более стабильные показатели при анализе и отфильтровал колонку
#
# #### Анализ распределения "tickets_count":
# - Также присутствуют выбросы, которые сильно искажают результаты исследования
# - Среднее значение рядом с медианой, что говорит о нормальном распределении данных
# - Посмотрев на диаграмму распредлеения можно сделать вывод, что чаще всего люди заказывают 2-3 билета за раз, скорее всего есть акции или скидка при заказе более одного билета
# - Также принял решение об удалении аномальных значений.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# * В целом с задачей справились, предобработку провели!
#
#
# * Хорошо, что сопровождаешь графики заголовком и всеми необходимыми подписями - сразу понятно, что изображено на нем и как его читать!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * Сейчас ты фиксируешь общие выводы только в конце раздела. Чтобы в работе был понятный сторителлинг, стоит также фиксировать промежуточные свои наблюдения для каждого из шагов: почему мы ничего не стали делать с пропусками и перешли к следующему шагу? Как приняли решение скорректировать тип у тех или иных столбцов? Действительно ли наши категориальные признаки в порядке и не требуют нормализации? Действительно ли в числовых признаках есть выбросы, какова их предполагаемая природа возникновения? Почему мы решили отбросить выбросы в выручке? Почему решили не отбрасывать выбросы в количестве билетов?
#
#
# * Для удобства анализа гистограмму для определенного признака стоит строить рядом с боксплотом, чтобы можно было сопоставлять информацию из них. Можно даже создать пользовательскую функцию, которая будет принимать на вход признак и выводить для него сразу два типа визуализации в одном графике ([пример](https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/)).
#
#
# </div>
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# * Важно заметить отрицательных значений выручки - возможно, это какие-то возвраты. По-хорошему, их тоже следовало бы исключить, чтобы не завышать количество валидных транзакций на пользователя. Перед этим не забываем проверить, какой процент данных потеряем, не критично ли это.
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отлично, этап предобаботки выполнен корректно

# %% [markdown]
# ---
#
# ### 3. Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# **Задача 3.1.** Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %%
#Сортирую данные по времени совершения заказа
df = df.sort_values(by='order_dt')

# %%
#Построю профиль пользователя с помощью группировки и агрегации соответствующих полей

#Выбираю поля и агрегирующие функции для них
aggregations = {
    'order_dt': ['min', 'max'],
    'device_type_canonical': 'first',
    'region_name': 'first',
    'service_name': 'first',
    'event_type_main': 'first',
    'order_id': 'count',
    'revenue_rub': 'mean',
    'tickets_count': 'mean'
}

# %%
#Для каждого пользователя делаю агрегацию соответствующих полей
user = df.groupby('user_id').agg(aggregations).copy()
user
# Out:
#                   order_dt            device_type_canonical  \
#                        min        max                 first
# user_id
# 0002849b70a3ce2 2024-08-20 2024-08-20                mobile
# 0005ca5e93f2cf4 2024-07-23 2024-10-06                mobile
# 000898990054619 2024-07-13 2024-10-23                mobile
# 00096d1f542ab2b 2024-08-15 2024-08-15               desktop
# 000a55a418c128c 2024-09-29 2024-10-15                mobile
# ...                    ...        ...                   ...
# fff13b79bd47d7c 2024-07-16 2024-10-31                mobile
# fff32fc9ad0f9f6 2024-08-15 2024-10-28               desktop
# fffcd3dde79eb2c 2024-06-20 2024-10-30               desktop
# fffeeb3c120cf0b 2024-09-24 2024-09-24               desktop
# ffff00725179321 2024-09-25 2024-09-25                mobile
#
#                           region_name        service_name event_type_main  \
#                                 first               first           first
# user_id
# ...

# %%
#Считаем среднее время между заказами, прийдется обращаться к исходному датафрейму

#Считаем разницу между заказами в днях для каждого пользователя через акцессор 
df['avg_days'] = df.groupby('user_id')['order_dt'].diff().dt.days

# %%
#Считаем среднию разницу по полю df['avg_days'] для каждого пользователя
avg_days_diff = df.groupby('user_id')['avg_days'].mean()

# %%
#Добавляем эту колонку к профилю пользователя
user['avg_days_between_orders'] = avg_days_diff

# %%
#Проверяем результат
user.columns.to_list()
# Out:
# [('order_dt', 'min'),
#  ('order_dt', 'max'),
#  ('device_type_canonical', 'first'),
#  ('region_name', 'first'),
#  ('service_name', 'first'),
#  ('event_type_main', 'first'),
#  ('order_id', 'count'),
#  ('revenue_rub', 'mean'),
#  ('tickets_count', 'mean'),
#  ('avg_days_between_orders', '')]

# %%
#Сохраняю количество строк исходного датасета
user_shape = user.shape[0]
user_shape
# Out:
# 21831

# %%
#Создаю два новых поля с бинарными признаками с помощью масок
#Пользователь с 2-мя и более заказов
user['is_two'] = (user['order_id']['count'] >= 2)

#Пользователь с 5-ю и более заказами
user['is_five'] = (user['order_id']['count'] >= 5)

# %%
#Проверяю два новых столбца
user.head(3)
# Out:
#                   order_dt            device_type_canonical  \
#                        min        max                 first
# user_id
# 0002849b70a3ce2 2024-08-20 2024-08-20                mobile
# 0005ca5e93f2cf4 2024-07-23 2024-10-06                mobile
# 000898990054619 2024-07-13 2024-10-23                mobile
#
#                           region_name  service_name event_type_main order_id  \
#                                 first         first           first    count
# user_id
# 0002849b70a3ce2    Каменевский регион  Край билетов           театр        1
# 0005ca5e93f2cf4    Каменевский регион     Мой билет        выставки        2
# 000898990054619  Североярская область   Лови билет!          другое        3
#
#                  revenue_rub tickets_count avg_days_between_orders is_two  \
#                         mean          mean
# user_id
# 0002849b70a3ce2  1521.940000      4.000000                     NaN  False
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Также есть довольно удобный метод [assign](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html), позволяющий дополнять таблицу новыми рассчитанными столбцами.
#
#     Тогда создание всего профиля можно будет записать красивым и удобным по структуре кодом.
#
#     <details> <summary> <span style='color:blue' > Развернуть подробнее. </span> </summary>
#
#     ```python
#     profiles = (df
#             # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
#             .sort_values(by='order_ts')
#             # Затем группируем по номеру пользователя и агрегируем данные:
#             .groupby('user_id')
#             .agg(
#                 # Находим первую и последнюю даты заказа:
#                 first_order_dt=('order_dt','min'),
#                 last_order_dt=('order_dt','max'),
#                 # Находим устройства, регион, название билетного партнера и тип мероприятия первого заказа:
#                 first_device=('device_type_canonical','first'),
#                 first_region_name=('region_name','first'),
#                 first_service_name=('service_name','first'),
#                 first_event_type=('event_type_main','first'),
#                 # Подсчитваем количество заказов:
#                 total_orders=('order_id','nunique'),
#                 # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
#                 avg_revenue_rub=('revenue_rub','mean'),
#                 avg_tickets_count=('tickets_count','mean'),
#                 # Считаем среднее количество дней между покупками:
#                 avg_days_since_prev=('days_since_prev','mean')
#             )
#             # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
#             .assign(
#                 is_two = lambda x: x['total_orders'] >= 2,
#                 is_five = lambda x: x['total_orders'] >= 5
#             )
#             .reset_index()
#     )
#     ```
#     </details>
#
#
#
# </div>

# %% [markdown]
# ---
#
# **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %%
# Расчет общего количества пользователей в выборке
print(f"Всего у нас {user.shape[0]} пользователей")
# Out:
# Всего у нас 21831 пользователей

# %%
# Средняя выручка с одного заказа
avg_rev = user['revenue_rub'].mean()

print(f"Средняя выручка: {avg_rev}")
# Out:
# Средняя выручка: mean    544.795848
# dtype: float64

# %%
two_and_more = user['is_two'].mean() * 100
print(f"Доля пользователей с 2-мя и более заказами: {round(two_and_more, 2)}% от общего количества пользователей")
# Out:
# Доля пользователей с 2-мя и более заказами: 61.7% от общего количества пользователей

# %%
five_and_more = user['is_five'].mean()*100
print(f"Доля пользователей с 5-ю и более заказами: {round(five_and_more, 2)}% от общего количества пользователей")
# Out:
# Доля пользователей с 5-ю и более заказами: 29.0% от общего количества пользователей

# %% [markdown]
# #### Анализ статисчтических показателей - число заказов

# %%
#Статистические показатели по общему числу заказов для данных сгруппированных по пользователям
user['order_id'].describe()
# Out:
#               count
# count  21831.000000
# mean      13.156750
# std      121.484319
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max    10155.000000

# %%
#Посмотрим на показатели без выбросов

#Фильтруем данные с помощью процентилей
order_upper_limit = user[('order_id', 'count')].quantile(0.99)

#Создаем новый отфильтрованный датасет
filtered_order_id = user[user[('order_id', 'count')] <= order_upper_limit]

# %%
#Проверяю результат
filtered_order_id['order_id'].describe()
# Out:
#               count
# count  21612.000000
# mean       6.475292
# std       14.205046
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max      151.000000

# %% [markdown]
# Лучше, но максимальное значение слишком сильно выбивается из основной массы значений и сильно влияет на результаты

# %%
#Отфильтруем данные до 95 процентиля
order_upper_limit = user[('order_id', 'count')].quantile(0.95)

#Переназначаем отфильтрованный датафрейм
filtered_order_id = user[user[('order_id', 'count')] <= order_upper_limit]

# %%
#Смотрим результаты
filtered_order_id['order_id'].describe()
# Out:
#               count
# count  20741.000000
# mean       4.049419
# std        5.114505
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max       31.000000

# %% [markdown]
# Еще лучше

# %%
#Переназначаю отфильтрованную колонку для датасета
user = user[user[('order_id', 'count')] <= order_upper_limit]

# %%
#Смотрю на размер отфильтрованного датафрейма
user.shape
# Out:
# (20741, 12)

# %%
#Считаю количество отфильтрованных данных
filtered_order_id = user_shape - user.shape[0] 
print(f"Количество отфильтрованных строк: {filtered_order_id}")
# Out:
# Количество отфильтрованных строк: 1090

# %%
#Считаю относительный показатель отфильтрованных данных
filtered_share_order_id = (filtered_order_id / user_shape) * 100
print(f"Относительная величина отфильтрованных данных: {round(filtered_share_order_id, 2)}")
# Out:
# Относительная величина отфильтрованных данных: 4.99

# %% [markdown]
# #### Анализ статистических показателей - среднее число билетов в заказе

# %%
#Смотрю название колонок
user.columns.to_list()
# Out:
# [('order_dt', 'min'),
#  ('order_dt', 'max'),
#  ('device_type_canonical', 'first'),
#  ('region_name', 'first'),
#  ('service_name', 'first'),
#  ('event_type_main', 'first'),
#  ('order_id', 'count'),
#  ('revenue_rub', 'mean'),
#  ('tickets_count', 'mean'),
#  ('avg_days_between_orders', ''),
#  ('is_two', ''),
#  ('is_five', '')]

# %%
#Смотрю статистические показатели по среднему количеству билетов в заказе
user['tickets_count'].describe()
# Out:
#                mean
# count  20741.000000
# mean       2.740585
# std        0.923962
# min        1.000000
# 25%        2.000000
# 50%        2.750000
# 75%        3.142857
# max        6.000000

# %%
#Хочу лучше понять распределение значений, поэтому визуализирую данные с помощью гистограммы
plt.figure(figsize=(6,4))

plt.hist(user['tickets_count'], bins=10, edgecolor='black')

plt.grid(True)
plt.title('Среднее количество билетов в заказе')
plt.xlabel('Размер заказа')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# #### Анализ статистических показателей - среднее количество дней между покупками

# %%
user.columns.to_list()
# Out:
# [('order_dt', 'min'),
#  ('order_dt', 'max'),
#  ('device_type_canonical', 'first'),
#  ('region_name', 'first'),
#  ('service_name', 'first'),
#  ('event_type_main', 'first'),
#  ('order_id', 'count'),
#  ('revenue_rub', 'mean'),
#  ('tickets_count', 'mean'),
#  ('avg_days_between_orders', ''),
#  ('is_two', ''),
#  ('is_five', '')]

# %%
#Смотрим на статистические показатели по количеству средних дней между заказами
#В данных много пропусков, но они не влияют на результат фильтрации

user['avg_days_between_orders'].describe()
# Out:
# count    12379.000000
# mean        17.104869
# std         22.857865
# min          0.000000
# 25%          1.000000
# 50%          9.500000
# 75%         22.250000
# max        148.000000
# Name: avg_days_between_orders, dtype: float64

# %%
#Отфильтруем данные по 99-му процентилю и посмотрим разницу

avg_days_upper_limit = user['avg_days_between_orders'].quantile(0.99)

filtered_avg_days = user[user['avg_days_between_orders'] <= avg_days_upper_limit]

# %%
#Смотрим на результат после фильтрации
filtered_avg_days['avg_days_between_orders'].describe()
# Out:
# count    12257.000000
# mean        16.000666
# std         20.080116
# min          0.000000
# 25%          1.000000
# 50%          9.333333
# 75%         21.666667
# max        115.000000
# Name: avg_days_between_orders, dtype: float64

# %% [markdown]
# Максимальное значение по прежнему очень большое, фильтруем сильнее

# %%
#Отфильтруем данные по 95-му процентилю

avg_days_upper_limit = user['avg_days_between_orders'].quantile(0.95)

filtered_avg_days = user[user['avg_days_between_orders'] <= avg_days_upper_limit]

# %%
#Смотрим на результат после фильтрации
filtered_avg_days['avg_days_between_orders'].describe()
# Out:
# count    11771.000000
# mean        13.158157
# std         14.387880
# min          0.000000
# 25%          0.666667
# 50%          8.777778
# 75%         19.500000
# max         64.000000
# Name: avg_days_between_orders, dtype: float64

# %% [markdown]
# Больше похоже на правду, среднее значение стало ближе к медиане, но все равно разница большая, хочу посмотреть на диаграмму размаха

# %%
#Смотрим на диаграмму размаха с выбросами
plt.figure(figsize=(6, 4))

plt.boxplot(filtered_avg_days['avg_days_between_orders'], vert=False)
plt.grid(True)
plt.xlabel('Средняя разница в днях')
# Out:
# Text(0.5, 0, 'Средняя разница в днях')

# %%
#Смотрим на диаграмму размаха без выбросов

plt.figure(figsize=(6, 4))

plt.boxplot(filtered_avg_days['avg_days_between_orders'], vert=False, showfliers=False)
plt.grid(True)
plt.xlabel('Средняя разница в днях')
# Out:
# Text(0.5, 0, 'Средняя разница в днях')

# %% [markdown]
# #### Считаю величины (относительные, абсолютные) отфильтрованных данных

# %%
user_new_shape = user.shape[0]

# %%
#Перезаписываю значение процентилей, не трогая пустые значения
avg_days_upper_limit = user['avg_days_between_orders'].dropna().quantile(0.95)

# %%
#Создаем маску чтобы сохранить пустые значения и провести фильтрацию
mask = (user['avg_days_between_orders'] <= avg_days_upper_limit) | (user['avg_days_between_orders'].isna())

# %%
#Применяю фильтрацию по маске
user =  user[mask].copy()

# %%
#Проверяем размер датасета после фильтрации
user.shape[0]
# Out:
# 20133

# %%
#Считаем колиечство отфильтрованных строк 
filtered_user_new = user_new_shape - user.shape[0]
print(f"Всего было удалено: {filtered_user_new} строк")
# Out:
# Всего было удалено: 608 строк

# %%
total_filtered = filtered_order_id + filtered_user_new
total_filtered
# Out:
# 1698

# %%
print(f"В сумме после фильтрации 2-ух колонок (order_id и avg_days_between_orders) было отфильтровано {total_filtered} колонок")
# Out:
# В сумме после фильтрации 2-ух колонок (order_id и avg_days_between_orders) было отфильтровано 1698 колонок

# %%
total_filtered_share = (total_filtered / user_shape) * 100
total_filtered_share
# Out:
# 7.777930465851313

# %%
print(f"Относительная величина отфильтрованных данных составляет: {round(total_filtered_share, 2)}% от всего датасета")
# Out:
# Относительная величина отфильтрованных данных составляет: 7.78% от всего датасета

# %% [markdown]
# #### Промежуточные итоги по "Шагу 3(Создание профиля пользователя)":
#
# - Датафрейм был отсортирован по времени
# - Был создан профиль пользователя за счет группировки датафрейма по "user_id", так же провел агрегацию нужных полей (21847 строк)
# - Была создана новая колонка со средней разницей дней между заказами, там где разницы нету, появляется NaN-значение
# - Также были добавлены 2 новые колонки, которые считают пользователей совершивших 2 и более заказа, и 5 и более заказов
# - Были расчитаны значения по количеству пользователей, средней выручке на заказ, доли пользователей, совершивших несколько заказов
# - Были проанализированны и визуализированы статистические показатели в колонках с (общим числом заказов, среднее количество билетов в заказе, средним количеством дней между покупками)
# - Было отфильтрованно 7,78%(1700 строк) данных, которые являлись аномальными и сильно искажали результаты анализа
#
# Выводы по общему числу заказов:
# - Среднее значение число заказов 13 штук на человека, что является большим количеством
# - Медиана равна 2, соответственно есть выбросы или аномальные значения
# - Стандартное отклонение 121.5, что потверждает информацию о выбросах
# - Минимальное значение - 1, макисмальное - 10.168 (Аномалия)
# - Были посчитаны статистические показатели для данных, отфильтрованных по 95-му процентилю
# - Затем было отфильтрованно 5% данных
#
#
# Выводы по среднему числу билетов в заказе:
# - Видно, что среднее значение и медиана почти идеально совпадают, что говорит о нормальном распределении
# - Стандартное отклонение тоже небольшое, что говорит об отсутствии выбросов
# - Максимальное значение это 6 билетов в заказе, что является вполне адекватным значением
# - Межквартильный размах лежит в диапазоне значений (от 2 до 3.15)
# - Принял решение, что никаких фильтраций проводить не буду
#
# Выводы по среднему количеству дней между заказами:
# - Среднее значение и медиана сильно отличаются
# - Максимальное значение очень далеко от минимального, что говорит о наличии выбросов
# - Была построена гистограмма размаха, на которой видны аномально высокие значения
# - Принял решение отфильтровать данные по 95процентилю, чтобы уменьшить большую изменивость данных

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Здесь  все супер, выполнены все необходимые шаги!
#
#
# Как рекомендация, было бы не лишним также проверить, насколько изменилась средняя выручка после удаления выбросов. Посмотреть на распределение данных с помощью гистограмм и диаграмм размаха.
#
#
# Так же, хорошо было бы лучше сначала обосновать выбор стратегии по обработке, а потом уже приступить к ее выполнению при необходимости.

# %% [markdown]
# ---
#
# ### 4. Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# **Задача 4.1.1.** Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %%
user.columns.to_list()
# Out:
# [('order_dt', 'min'),
#  ('order_dt', 'max'),
#  ('device_type_canonical', 'first'),
#  ('region_name', 'first'),
#  ('service_name', 'first'),
#  ('event_type_main', 'first'),
#  ('order_id', 'count'),
#  ('revenue_rub', 'mean'),
#  ('tickets_count', 'mean'),
#  ('avg_days_between_orders', ''),
#  ('is_two', ''),
#  ('is_five', '')]

# %%
#Группировка и подсчет пользователей по типу их первого мероприятия
event_type_group = user['event_type_main'].value_counts()
event_type_group.sort_values(ascending=False)
# Out:
# first
# концерты    8896
# другое      5003
# театр       3952
# стендап     1039
# спорт        762
# выставки     387
# ёлки          94
# Name: count, dtype: int64

# %%
#Подсчет доли пользователей в разрезе их первого меропрития
event_type_group_share = user['event_type_main'].value_counts(normalize=True)
event_type_group_share
# Out:
# first
# концерты    0.441862
# другое      0.248497
# театр       0.196295
# стендап     0.051607
# спорт       0.037848
# выставки    0.019222
# ёлки        0.004669
# Name: proportion, dtype: float64

# %%
#Группировка и подсчет пользователей в разрезе устройства первой покупки
device_group = user['device_type_canonical'].value_counts()
device_group.sort_values(ascending=False)
# Out:
# first
# mobile     16704
# desktop     3429
# Name: count, dtype: int64

# %%
#Относительные показатели по используемым для первого заказа устройствам
device_group_share = user['device_type_canonical'].value_counts(normalize=True)
device_group_share
# Out:
# first
# mobile     0.829683
# desktop    0.170317
# Name: proportion, dtype: float64

# %%
#Смотрим распределение данных по региону проведения мероприятия из первого заказа
region_group = user['region_name'].value_counts()
region_group
# Out:
# first
# Каменевский регион          6528
# Североярская область        3489
# Широковская область         1147
# Озернинский край             638
# Малиновоярский округ         503
#                             ...
# Залесский край                 2
# Верхозёрский край              1
# Светолесский край              1
# Сосноводолинская область       1
# Яснопольский округ             1
# Name: count, Length: 81, dtype: int64

# %%
#Считаем относительные показатели по регионам для первого мероприятия
region_group_share = user['region_name'].value_counts(normalize=True)
region_group_share
# Out:
# first
# Каменевский регион          0.324244
# Североярская область        0.173298
# Широковская область         0.056971
# Озернинский край            0.031689
# Малиновоярский округ        0.024984
#                               ...
# Залесский край              0.000099
# Верхозёрский край           0.000050
# Светолесский край           0.000050
# Сосноводолинская область    0.000050
# Яснопольский округ          0.000050
# Name: proportion, Length: 81, dtype: float64

# %%
#Распределение пользователей по операторам, продавшим билеты на первый заказ
service_group = user['service_name'].value_counts()
service_group
# Out:
# first
# Билеты без проблем        4793
# Мой билет                 2780
# Лови билет!               2628
# Билеты в руки             2355
# Облачко                   2043
# Весь в билетах            1181
# Лучшие билеты             1114
# Прачечная                  536
# Край билетов               424
# Дом культуры               327
# Яблоко                     297
# Тебе билет!                293
# Городской дом культуры     208
# За билетом!                198
# Мир касс                   186
# Быстробилет                157
# Show_ticket                151
# Выступления.ру              91
# Восьмёрка                   80
# Быстрый кассир              48
# Crazy ticket!               45
# Радио ticket                34
# Росбилет                    34
# Реестр                      26
# Телебилет                   25
# Цвет и билет                20
# Шоу начинается!             18
# КарандашРУ                  13
# Кино билет                   9
# Вперёд!                      7
# ...

# %%
#Считаем относительные показатели по операторам билетов
service_group_share = user['service_name'].value_counts(normalize=True)
service_group_share
# Out:
# first
# Билеты без проблем        0.238067
# Мой билет                 0.138082
# Лови билет!               0.130532
# Билеты в руки             0.116972
# Облачко                   0.101475
# Весь в билетах            0.058660
# Лучшие билеты             0.055332
# Прачечная                 0.026623
# Край билетов              0.021060
# Дом культуры              0.016242
# Яблоко                    0.014752
# Тебе билет!               0.014553
# Городской дом культуры    0.010331
# За билетом!               0.009835
# Мир касс                  0.009239
# Быстробилет               0.007798
# Show_ticket               0.007500
# Выступления.ру            0.004520
# Восьмёрка                 0.003974
# Быстрый кассир            0.002384
# Crazy ticket!             0.002235
# Радио ticket              0.001689
# Росбилет                  0.001689
# Реестр                    0.001291
# Телебилет                 0.001242
# Цвет и билет              0.000993
# ...

# %% [markdown]
# #### Промежуточные итоги по заданию 4.1.1
# - Видим, что самая популярная категория мероприятий - это концерты (почти половина всех первых мероприятий)
# - Клиенты заказывают билеты через телефон в 4 из 5 случаев
# - Самые популярные регионы для проведения первого мероприятия это Каменевский регион и Североярская область. Два этих региона занимают половину данных в колонке с первыми мероприятиями
# - Люди купившие билеты на свое первое мероприятие используют в основном пять компаний. Почти четверть всех заказов были оформлены через компанию "Билеты без проблем", далее по-популярномсти идут компании (Мой билет, Лови билет!, Билеты в руки, Облачко) на каждую из этих компаний приходится в районе 10% заказов первых билетов на мероприятия

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# По результатам всё верно
#
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Можно создать пользовательскую функцию, чтобы не прописывать практически один и тот же код несколько раз
#
#         def segment_summary(df, column):
#         seg = (df.groupby(column).agg(users_count=('user_id', 'nunique')) .reset_index().sort_values('users_count', ascending=False))
#         seg['users_share'] = (seg['users_count'] / seg['users_count'].sum() *100)
#         seg['users_share'] = seg['users_share'].round(2)
#         return seg
#
#
# * Визуализировать полученные данные,
#
# * По выводам хорошо бы показать общую картину: как распределяются пользователи по сегментам, какие группы преобладают, какие встречаются реже и почему так может быть. А уже после этого привести конкретные значения - как подтверждение своих наблюдений.

# %%
#Попробую сделать то же самое через пользовательскую функцию

#Создаю список колонок 
columns = ['event_type_main', 'device_type_canonical', 'region_name', 'service_name']

def segment_summary(df, columnn):
    seg = (df.groupby(column).agg(users_count=('user_id', 'nunique')) .reset_index().sort_values('users_count', ascending=False))
    seg['users_share'] = (seg['users_count'] / seg['users_count'].sum() *100)
    seg['users_share'] = seg['users_share'].round(2)
    return seg

# %%
#Пройдусь циклом по каждой колонке
for column in columns:
    result = segment_summary(df, column)
    print(result)
# Out:
#   event_type_main  users_count  users_share
# 2        концерты        13339        34.28
# 1          другое         9251        23.78
# 5           театр         8238        21.17
# 4         стендап         3241         8.33
# 3           спорт         2532         6.51
# 0        выставки         1600         4.11
# 6            ёлки          707         1.82
#   device_type_canonical  users_count  users_share
# 1                mobile        19699        73.56
# 0               desktop         7082        26.44
#                  region_name  users_count  users_share
# 23        Каменевский регион        10556        18.64
# 60      Североярская область         6683        11.80
# 77       Широковская область         3244         5.73
# 45          Озернинский край         2472         4.37
# 41      Малиновоярский округ         1873         3.31
# ..                       ...          ...          ...
# 80        Яснопольский округ           11         0.02
# ...

# %% [markdown]
# ---
#
# **Задача 4.1.2.** Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %%
#Вывожу названия колонок
user.columns.to_list()
# Out:
# [('order_dt', 'min'),
#  ('order_dt', 'max'),
#  ('device_type_canonical', 'first'),
#  ('region_name', 'first'),
#  ('service_name', 'first'),
#  ('event_type_main', 'first'),
#  ('order_id', 'count'),
#  ('revenue_rub', 'mean'),
#  ('tickets_count', 'mean'),
#  ('avg_days_between_orders', ''),
#  ('is_two', ''),
#  ('is_five', '')]

# %%
#Убираю мультииндекс у датафрейма, чтобы можно было нормально группировать данные
user.columns = ['_'.join(col).strip() for col in user.columns.values]

# %%
#Смотрим на обновленное название колонок
user.columns.to_list()
# Out:
# ['order_dt_min',
#  'order_dt_max',
#  'device_type_canonical_first',
#  'region_name_first',
#  'service_name_first',
#  'event_type_main_first',
#  'order_id_count',
#  'revenue_rub_mean',
#  'tickets_count_mean',
#  'avg_days_between_orders_',
#  'is_two_',
#  'is_five_']

# %%
#Выводим долю пользователей, совершивших 2 и более заказов в разрезе типа мероприятия
event_2_orders_plus = user.groupby('event_type_main_first')['is_two_'].mean() * 100
event_2_orders_plus
# Out:
# event_type_main_first
# выставки    61.757106
# другое      56.366180
# концерты    58.947842
# спорт       53.937008
# стендап     58.229066
# театр       60.728745
# ёлки        55.319149
# Name: is_two_, dtype: float64

# %%
#Визуализируем event_2_orders_plus, сравнивать категории легче всего с помощью barplot
plt.figure(figsize=(9,7))

#Настраиваем отображение графика
plt.bar(event_2_orders_plus.index, event_2_orders_plus.values)
plt.grid(True)
plt.title('Доли пользователей, совершивших 2 и более заказов в разрезе типа их первого мероприятия')
plt.ylabel('Доля пользователей, которые вернулись')

#Добавим линию среднего значения чтобы было легче сравнивать
avg_value = user['is_two_'].mean()*100
plt.axhline(avg_value, color='red')

plt.show()

# %%
#Выводим долю пользователей, совершивших 2 и более заказов в разрезе типа устройства
device_2_orders_plus = user.groupby('device_type_canonical_first')['is_two_'].mean()*100
device_2_orders_plus
# Out:
# device_type_canonical_first
# desktop    60.863225
# mobile     57.974138
# Name: is_two_, dtype: float64

# %%
#Визуализируем  device_2_orders_plus
plt.figure(figsize=(9,7))

#Настраиваем отображение графика
plt.bar(device_2_orders_plus.index, device_2_orders_plus.values)
plt.grid(True)
plt.title('Доли пользователей, совершивших 2 и более заказов в разрезе типа устрайства первого заказа')
plt.ylabel('Доля пользователей, которые вернулись')
plt.show()

# %%
#Выводим долю пользователей, совершивших 2 и более заказа в разрезе региона проведения первого мероприятия
region_2_orders_plus = user.groupby('region_name_first')['is_two_'].mean()*100
region_2_orders_plus
# Out:
# region_name_first
# Белоярская область      58.823529
# Берестовский округ      63.636364
# Берёзовская область     62.745098
# Боровлянский край       51.515152
# Верховинская область    50.000000
#                           ...
# Шанырский регион        63.310962
# Широковская область     62.074978
# Яблоневская область     57.397959
# Ягодиновская область    63.793103
# Яснопольский округ       0.000000
# Name: is_two_, Length: 81, dtype: float64

# %%
#Хочу посмотреть статистические показатели по всему набору данных
region_2_orders_plus.describe()
# Out:
# count     81.000000
# mean      52.571932
# std       15.716510
# min        0.000000
# 25%       49.450549
# 50%       54.838710
# 75%       60.635697
# max      100.000000
# Name: is_two_, dtype: float64

# %%
#Выбираем топ 10 регионов по количеству пользователей
top_10_regions = user['region_name_first'].value_counts().head(10).index

# %%
#Выбираем регионы из нашего списка (Топ 10 регионов) с помощью маски
region_top10 = user[user['region_name_first'].isin(top_10_regions)]

# %%
#Считаем долю пользователей, которые вернулись в разерезе 10 самых популярных регионов для первого мероприятия
region_2_orders_top10 = region_top10.groupby('region_name_first')['is_two_'].mean() * 100

# %%
#Визуализируем и сравниванием
region_2_orders_top10 = region_2_orders_top10.sort_values(ascending=False)

plt.figure(figsize=(9,7))

#Настраиваем отображение графика
region_2_orders_top10.plot(kind='bar')
plt.grid(True)
plt.xticks(rotation=45)
plt.title('Доля вернувшихся клиентов в разрезе 10 самый популярных регионов для первого меропрития клиетов')
plt.ylabel('Доля в процентах')

# Добавляю линию со средним значение
avg_top_10 = region_2_orders_top10.mean()
plt.axhline(avg_top_10, color='red')

plt.show()

# %%
#Выводим долю пользователей, совершивших 2 и заказов в разрезе билетного оператора, продавшего билеты на первый заказ
service_2_orders_plus = user.groupby('service_name_first')['is_two_'].mean()*100
service_2_orders_plus.sort_values(ascending=False)
# Out:
# service_name_first
# Зе Бест!                  100.000000
# Билет по телефону          83.333333
# Быстрый кассир             81.250000
# Реестр                     76.923077
# Crazy ticket!              68.888889
# Восьмёрка                  66.250000
# Show_ticket                63.576159
# Край билетов               62.735849
# Дом культуры               61.467890
# Выступления.ру             60.439560
# Цвет и билет               60.000000
# Мир касс                   59.677419
# Весь в билетах             59.610500
# Билеты в руки              59.575372
# Прачечная                  59.328358
# Лучшие билеты              58.976661
# Росбилет                   58.823529
# Облачко                    58.688204
# Тебе билет!                58.361775
# Лови билет!                58.219178
# Мой билет                  58.129496
# За билетом!                58.080808
# Быстробилет                57.961783
# Билеты без проблем         57.291884
# Городской дом культуры     57.211538
# ...

# %%
service_2_orders_plus.describe()
# Out:
# count     34.000000
# mean      58.464225
# std       14.230082
# min       27.777778
# 25%       57.160027
# 50%       58.755867
# 75%       61.210808
# max      100.000000
# Name: is_two_, dtype: float64

# %%
#Считаем 10 самых популярных билетных сервиса для первого заказа
top_10_services = user['service_name_first'].value_counts().head(10).index

# %%
#Вывожу названия самых популярных сервисов(индексы) для первого заказа
top_10_services.sort_values(ascending=False).to_list()
# Out:
# ['Прачечная',
#  'Облачко',
#  'Мой билет',
#  'Лучшие билеты',
#  'Лови билет!',
#  'Край билетов',
#  'Дом культуры',
#  'Весь в билетах',
#  'Билеты в руки',
#  'Билеты без проблем']

# %%
#Выбираем сервисы из нашего списка (Топ 10 сервисов) с помощью маски
services_top10 = user[user['service_name_first'].isin(top_10_services)]

# %%
#Считаем долю пользователей, которые вернулись в разерезе 10 самых популярных сервисов для первого мероприятия
services_2_orders_top10 = services_top10.groupby('service_name_first')['is_two_'].mean() * 100

# %%
#Визуализируем и сравниваем
services_2_orders_top10 = services_2_orders_top10.sort_values(ascending=False)

plt.figure(figsize=(9,7))

#Настраиваем отображение графика
services_2_orders_top10.plot(kind='bar')
plt.grid(True)
plt.xticks(rotation=45)
plt.title('Доля вернувшихся клиентов в разрезе 10 самый популярных сервисов для первого меропрития клиетов')
plt.ylabel('Доля в процентах')

# Добавляю линию со средним значение
avg_services = services_2_orders_top10.mean()
plt.axhline(avg_services, color='red')

plt.show()

# %% [markdown]
# #### Промежуточные итоги по заданию 4.1.2
# При анализе людей, которые возвращаются на сервис Яндекс Афиша, стало ясно:
# - Что тип мероприятия и тип устройства, для первого заказа не влияют на возврат пользователей
# - В топ 10 регионах по популярности для первого мероприятия клиентов, нету аномальных результатов, все регионы имеют долю вернувшихся клиентов от 52 до 65 %
# - То же самое можно сказать и про ТОП-10 сервисов по пулярности среди пользователей, покупающих в первый раз, все сервисы имеют примерно одинаковый процент возврата пользователей

# %% [markdown]
# ---
#
# **Задача 4.1.3.** Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %% [markdown]
# Гипотеза 1

# %%
#Выводим долю пользователей, совершивших 2 и более заказов в разрезе типа мероприятия
event_2_orders_plus = user.groupby('event_type_main_first')['is_two_'].mean() * 100
event_2_orders_plus.sort_values(ascending=False)
# Out:
# event_type_main_first
# выставки    61.757106
# театр       60.728745
# концерты    58.947842
# стендап     58.229066
# другое      56.366180
# ёлки        55.319149
# спорт       53.937008
# Name: is_two_, dtype: float64

# %% [markdown]
# Гипотеза 2

# %%
#Выводим самые активные регионы (Не только названия)
top_10_regions = user['region_name_first'].value_counts().head(10)
top_10_regions
# Out:
# region_name_first
# Каменевский регион      6528
# Североярская область    3489
# Широковская область     1147
# Озернинский край         638
# Малиновоярский округ     503
# Травяная область         451
# Шанырский регион         447
# Светополянский округ     426
# Речиновская область      409
# Яблоневская область      392
# Name: count, dtype: int64

# %%
#Посмотрим снижается ли процент возрата клиентов по мере уменьшения популярности региона
region_2_orders_top10 = region_top10.groupby('region_name_first')['is_two_'].mean() * 100
region_2_orders_top10
# Out:
# region_name_first
# Каменевский регион      59.175858
# Малиновоярский округ    53.876740
# Озернинский край        52.664577
# Речиновская область     60.635697
# Светополянский округ    63.145540
# Североярская область    60.934365
# Травяная область        58.314856
# Шанырский регион        63.310962
# Широковская область     62.074978
# Яблоневская область     57.397959
# Name: is_two_, dtype: float64

# %% [markdown]
# #### Промежуточный итог по заданию 4.1.3
#
# Гипотеза 1:
# - Тип мероприятия почти влияет на вероятность человека вернуться на Яндекс Афину
# - Пользователи у которых первый заказ был на спортивное мероприятие не возвращаются на Яндекс Афишу чаще чем это делают люди, у которых первое мероприятие было категории концерта
#
# Гипотеза 2:
# - Из собранной статистики, можно сделать вывод: потверждения, которое говорит, что популярные регионы для первого мероприятия у людей влияют на то, что человек вернется на платформу - не выявлено. В самом популярном регионе и регионе, который пользуется наименьшим спросом для первого мероприятия у людей, в выборке из 10 самых популярных регионов, процент возврата пользоваетелей почти одинаковый

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# * По выводам относительно гипотез все верно подмечено! Можно было бы еще сделать более яркий акцент на том, что в топ по повторным заказам вырвались регионы с ощутимо меньшим числом пользователей, а значит оценка показателя возвращаемости у них более чувствительна к колебаниям в количестве пользователей (1 дополнительный пользователь может существеннее повлиять на показатель, как в плюс, так и в минус).
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * В случае вывода неполного набора сегментов стоит указать, какой процент от выборки они составляют, чтобы было понимание, насколько большая часть данных осталась за пределами нашего обзора.
#
#
# * На графиках сегменты было бы логичнее отсортировать от большего к меньшему, поскольку большие сегменты представляют для нас больший интерес.
#
#
# * Также было бы неплохо добавить на графики линию среднего значения, чтобы было удобно сравнивать, какие сегменты и насколько отличаются от общего показателя по выборке. Это можно сделать с помощью `plt.axvline`, потребуется также добавить легенду.
#
#
#
# </div>

# %% [markdown]
# ---
#
# ## 4.2. Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
#
# **Задача 4.2.1.** Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %%
#Выводим названия всех колонок
user.columns.to_list()
# Out:
# ['order_dt_min',
#  'order_dt_max',
#  'device_type_canonical_first',
#  'region_name_first',
#  'service_name_first',
#  'event_type_main_first',
#  'order_id_count',
#  'revenue_rub_mean',
#  'tickets_count_mean',
#  'avg_days_between_orders_',
#  'is_two_',
#  'is_five_']

# %%
#У нас есть средняя выручка на заказ для каждого пользователя
#Надо посчитать среднюю выручку с билета для каждого пользователя

#Можем среднюю выручку поделить на среднее количество билетов у одного пользователя, чтобы узнать цену на билет

user['avg_revenue_rub'] = user['revenue_rub_mean'] / user['tickets_count_mean']

# %%
#Смотрим результат 
user.head()
# Out:
#                 order_dt_min order_dt_max device_type_canonical_first  \
# user_id
# 0002849b70a3ce2   2024-08-20   2024-08-20                      mobile
# 000898990054619   2024-07-13   2024-10-23                      mobile
# 00096d1f542ab2b   2024-08-15   2024-08-15                     desktop
# 000a55a418c128c   2024-09-29   2024-10-15                      mobile
# 000cf0659a9f40f   2024-06-20   2024-06-21                      mobile
#
#                     region_name_first service_name_first  \
# user_id
# 0002849b70a3ce2    Каменевский регион       Край билетов
# 000898990054619  Североярская область        Лови билет!
# 00096d1f542ab2b    Каменевский регион       Край билетов
# 000a55a418c128c      Поленовский край      Лучшие билеты
# 000cf0659a9f40f   Широковская область        Лови билет!
#
#                 event_type_main_first  order_id_count  revenue_rub_mean  \
# user_id
# 0002849b70a3ce2                 театр               1       1521.940000
# ...

# %%
#Создаем 2 группы пользователей с помощью масок:

#Считаем среднюю цену за билет для пользователей с 1 заказом
one_order_users = user[user['is_two_'] == False]['avg_revenue_rub']

#Считаем среднюю цена за билет для пользователей с 2+ заказами
two_orders_plus_users = user[user['is_two_'] == True]['avg_revenue_rub']

# %%
#Строим сравнительные гистограммы сначала для пользователей с 1 заказом
plt.figure(figsize=(9, 6))

one_order_users.hist(bins=30, density=True, alpha=0.7, edgecolor='black')
plt.title('Распредлеение средней выручки с билета для пользователей с 1 заказом')
plt.xlabel('Средняя выручка с билета')
# Out:
# Text(0.5, 0, 'Средняя выручка с билета')

# %%
#Строим сравнительные гистограммы сначала для пользователей с 2 и более заказами
plt.figure(figsize=(9, 6))

two_orders_plus_users.hist(bins=30, density=True, alpha=0.7, edgecolor='black')
plt.title('Распредлеение средней выручки с билета для пользователей с 2 и более заказомами')
plt.xlabel('Средняя выручка с билета')
# Out:
# Text(0.5, 0, 'Средняя выручка с билета')

# %%
#Посмотрим распределение данных с наложением графиков друг на друга
plt.figure(figsize=(10, 6))


one_order_users.hist(bins=30, density=True, alpha=0.6, edgecolor='black', label='Пользователи с одним заказом')

two_orders_plus_users.hist(bins=30, density=True, alpha=0.6, edgecolor='black', label='Пользователи с 2 и более заказами')

plt.title('Сравнение распределения средней выручки с билета')
plt.xlabel('Средняя выручка с билета')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### Промежуточный итог по задаче 4.2.1:
# - Видно , что у пользователей с 1 заказом самая частая средняя цена на билет это 0 рублей, скорее всего человек регистрировался чтобы получить билет на бесплатное мероприятие.
# - По мере увеличение средней выручки с билета количество людей с 1 заказом сильно уменьшается
# - Сделаю вывод, что основное количество людей с 1 заказом сосредоточены в диапазоне средней выручки с билета от 0 до 100 рублей
#
# - Но для пользователей с 2 и более заказами, с ростом средней выручки с билета, увеличивается и количество наблюдений, это происходит до значения примерно равному 200 рублей, потом количество наблюдений тоже начинает стремительно падать
# - Основное количество пользователей с 2-мя и более заказами сосредоточено в диапазоне средней цены на билет в районе 100-350 рублей

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Можно чуть структурировать интерпретацию. Начни с общего сравнения (чем отличаются группы в целом), затем подчеркни ключевые различия в диапазонах (например, что возвращающиеся чаще в зоне от...–до... ₽, а однократные имеют больший разброс), и завершай возможными причинами — например, что нулевая выручка у однократных, вероятно, связана с возвратами, а крупные заказы — с разовыми покупками для групп.
#
# Еще можно добавить расчёты медины и среднего, чтобы понимать - имеется ли смещение и в какую сторону

# %% [markdown]
# ---
#
# **Задача 4.2.2.** Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %%
#Снова начала выделим 2 группы пользователей с помощью маски
#У первой 2 заказа = True и 5 заказов = False
#У второй 5 заказов = True

two_four_orders = user[(user['is_two_'] == True) & (user['is_five_'] == False)]
five_orders_plus = user[user['is_five_'] == True]

# %%
#Проверяю
#two_four_orders.head(3)
five_orders_plus.head(3)
# Out:
#                 order_dt_min order_dt_max device_type_canonical_first  \
# user_id
# 000cf0659a9f40f   2024-06-20   2024-06-21                      mobile
# 002b75ca606ba46   2024-07-08   2024-10-16                     desktop
# 002ec276eee9b0b   2024-07-10   2024-10-31                      mobile
#
#                    region_name_first service_name_first event_type_main_first  \
# user_id
# 000cf0659a9f40f  Широковская область        Лови билет!              концерты
# 002b75ca606ba46   Каменевский регион        Быстробилет              концерты
# 002ec276eee9b0b  Широковская область          Мой билет              концерты
#
#                  order_id_count  revenue_rub_mean  tickets_count_mean  \
# user_id
# 000cf0659a9f40f              13       1175.808462            3.307692
# 002b75ca606ba46               6        443.580000            3.000000
# 002ec276eee9b0b              22        811.942727            2.863636
#
# ...

# %%
#Теперь выбираю конкретное поле с выручков за заказ из этих двух датафреймов, которые мы будем сравнивать
two_four_orders = two_four_orders['revenue_rub_mean']

five_orders_plus = five_orders_plus['revenue_rub_mean']

# %%
#Строю гистрограммы распределения вместе с наложением (Выберу те же настройки)
plt.figure(figsize=(10,6))

two_four_orders.hist(bins=30, density=True, alpha=0.6, edgecolor='black', label='Пользователи с 2-мя и более заказами')

five_orders_plus.hist(bins=30, density=True, alpha=0.6, edgecolor='black', label='Пользователи с 5-ю и более заказами')

plt.title('Сравнение распределения средней выручки заказа')
plt.xlabel('Средняя выручка с заказа')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### Промежуточный итог по заданию 4.2.2
# - Видно, что в основном пользователи с 2-мя заказами концентрируются в районе меньшей цены (от 0 до 500) и их количество плавно снижается с увеличением средней выручки с заказа, наблюдается правое ассиметричное распределение
# - В то время как пользователи с 5 и более заказами в основном концентрируются вокруг значения 500-600 рублей, в целом распредление кажется более равномерным
# - В обоих случаях можно подметить сходство, что основное количество наблюдений сосредоточенно до цены в 1000 рублей

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# * С этой задачей тоже справились!
#
#
# * Плюс за грамотное оформление графиков - заголовок, подписи осей, легенда, поправка на размер выборки (`density`). По выводам тоже все верно подмечено!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
#
# * Чтобы удобно было сопоставлять доли пользователей по диапазонам цен, можно настроить единый размер бинов (`bins = 30` фиксирует количество бинов, но размер между сегментами будет отличаться, поскольку диапазон значений у них разный). Для этого в `bins` можно передать границы для формирования бинов с шагом: `bins = range(min_value, max_value+1, 50)`, максимальное и минимальное значения при этом определяем на всей выборке, а не отдельно для каждого сегмента.
#
# </div>

# %% [markdown]
# ---
#
# **Задача 4.2.3.** Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %%
#Опять же создаем разные группы пользователей с помощью масок

#от 1-го до 2 билетов
tickets_1_2 = user[(user['tickets_count_mean'] >= 1) & (user['tickets_count_mean'] < 2)]

#от 2 до 3 билетов
tickets_2_3 = user[(user['tickets_count_mean'] >= 2) & (user['tickets_count_mean'] < 3)]

#от 3 до 5 билетов(5 не стал включать)
tickets_3_5 = user[(user['tickets_count_mean'] >= 3) & (user['tickets_count_mean'] < 5)]

#от 5 и более билетов
tickets_5plus = user[user['tickets_count_mean'] >= 5]

# %%
# Смотрим количество пользователей в каждой группе
print(f"Количество пользователей у которых от 1 до 2 билетов: {len(tickets_1_2)}")
print(f"Количество пользователей у которых от 2 до 3 билетов: {len(tickets_2_3)}")
print(f"Количество пользователей у которых от 3 до 5 билетов: {len(tickets_3_5)}")
print(f"Количество пользователей у которых от 5 и более билетов: {len(tickets_5plus)}")
# Out:
# Количество пользователей у которых от 1 до 2 билетов: 2342
# Количество пользователей у которых от 2 до 3 билетов: 8530
# Количество пользователей у которых от 3 до 5 билетов: 8616
# Количество пользователей у которых от 5 и более билетов: 645

# %%
#Теперь для каждого сегемента(внутри него) мы должны посчитать количество клиентов, которые вернулись (is_two_ == True)
#Доля вернувшихся для tickets_1_2
return_1_2 = tickets_1_2[tickets_1_2['is_two_'] == True].shape[0]
share_1_2 = return_1_2 / len(tickets_1_2)
share_1_2 = round(share_1_2, 2)
share_1_2
# Out:
# 0.5

# %%
#Считаю количество вернувшихся для tickets_1_2
return_2_3 = tickets_2_3[tickets_2_3['is_two_'] == True].shape[0]

#Считаю долю
share_2_3 = return_2_3 / len(tickets_2_3)

#Округляю и вывожу
share_2_3 = round(share_2_3, 2)
share_2_3
# Out:
# 0.71

# %%
#Считаю количество вернувшихся для tickets_3_5
return_3_5 = tickets_3_5[tickets_3_5['is_two_'] == True].shape[0]

#Считаю долю
share_3_5 = return_3_5 / len(tickets_3_5)

#Округляю и вывожу
share_3_5 = round(share_3_5, 2)
share_3_5
# Out:
# 0.52

# %%
#Считаю количество вернувшихся для tickets_5plus
return_5plus = tickets_5plus[tickets_5plus['is_two_'] == True].shape[0]

#Считаю долю
share_5plus = return_5plus / len(tickets_5plus)

#Округляю и вывожу
share_5plus = round(share_5plus, 2)
share_5plus
# Out:
# 0.17

# %%
# Вывожу количество пользователей в каждой группе и долю вернувшихся
print(f"Группа билетов(1-2) Пользователей: {len(tickets_1_2)} Доля вернувшихся: {share_1_2}")
print(f"Группа билетов(2-3) Пользователей: {len(tickets_2_3)} Доля вернувшихся: {share_2_3}")
print(f"Группа билетов(3-5) Пользователей: {len(tickets_3_5)} Доля вернувшихся: {share_3_5}")
print(f"Группа билетов(5+) Пользователей: {len(tickets_5plus)} Доля вернувшихся: {share_5plus}")
# Out:
# Группа билетов(1-2) Пользователей: 2342 Доля вернувшихся: 0.5
# Группа билетов(2-3) Пользователей: 8530 Доля вернувшихся: 0.71
# Группа билетов(3-5) Пользователей: 8616 Доля вернувшихся: 0.52
# Группа билетов(5+) Пользователей: 645 Доля вернувшихся: 0.17

# %% [markdown]
# #### Промежуточный итог по заданию 4.2.3
# - 2 самые большие группы пользователей со средним количеством билетов это "2-3 билета" и "3-5 билетов", в сумме их больше 19 тысяч пользователей.
# - Самая большая доля повторных покупок принадлежит группе со средний количеством билетов от 2 до 3, пользователи с этим средним количеством билетов возвразатся чаще всего
# - Самый низкий показатель возврата, даже аномально низкий, у группы со средним колиечством билетов (5+)
#
# - Можно предположить, что клиенты покупающие по 2-3 билета это семьи, которые покупают билеты с одного аккаунта сразу для всех членов семьи или небольшие компании друзей, соответственно лояльность у них выше, семейные праздники чаще и люди снова пользуются сервисом.
#
# - А вот клиенты, покупающие 5 и более билетов это скорре всего пользователи, которые организовывавают корпоратив для организации или выезд для класса, такое происходит заметно реже, чем поход компании друзей на мероприятие

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно чуть развить вывод — предположить, почему пользователи, покупающие 2–3 билета, возвращаются чаще. Например, это могут быть небольшие компании или семьи, которые чаще ходят на мероприятия вместе, а значит, лояльность у них выше. А вот пользователи с 5+ билетами, вероятно, совершают разовые групповые покупки (например, для организации или класса), поэтому возвращаются реже

# %% [markdown]
# ---
#
# #### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# **Задача 4.3.1.** Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %%
#Смотрю название временных колонок
user.columns.to_list()
# Out:
# ['order_dt_min',
#  'order_dt_max',
#  'device_type_canonical_first',
#  'region_name_first',
#  'service_name_first',
#  'event_type_main_first',
#  'order_id_count',
#  'revenue_rub_mean',
#  'tickets_count_mean',
#  'avg_days_between_orders_',
#  'is_two_',
#  'is_five_',
#  'avg_revenue_rub']

# %%
#Создам колонку с днем недели из дня первой покупки
user['weekday'] = user['order_dt_min'].dt.day_name()

# %%
#Проверяю 
user.head(3)
# Out:
#                 order_dt_min order_dt_max device_type_canonical_first  \
# user_id
# 0002849b70a3ce2   2024-08-20   2024-08-20                      mobile
# 000898990054619   2024-07-13   2024-10-23                      mobile
# 00096d1f542ab2b   2024-08-15   2024-08-15                     desktop
#
#                     region_name_first service_name_first  \
# user_id
# 0002849b70a3ce2    Каменевский регион       Край билетов
# 000898990054619  Североярская область        Лови билет!
# 00096d1f542ab2b    Каменевский регион       Край билетов
#
#                 event_type_main_first  order_id_count  revenue_rub_mean  \
# user_id
# 0002849b70a3ce2                 театр               1       1521.940000
# 000898990054619                другое               3        767.213333
# 00096d1f542ab2b                 театр               1        917.830000
#
#                  tickets_count_mean  avg_days_between_orders_  is_two_  \
# user_id
# ...

# %%
# Теперь для каждого дня недели надо расчитать статистические показатели клиентов
# Количество клиентов (можно использовать строки с днем недели) и просуммируем значения True для поля is_two_ для подсчета вернувшихся клиентов
weekday_stats = user.groupby('weekday').agg(
    total_users=('weekday', 'count'),
    return_users=('is_two_', 'sum')
)

# %%
#Смотрим результаты
weekday_stats
# Out:
#            total_users  return_users
# weekday
# Friday            3073          1763
# Monday            2721          1641
# Saturday          3010          1775
# Sunday            2560          1452
# Thursday          2954          1693
# Tuesday           2941          1729
# Wednesday         2874          1718

# %%
#Считаем количество вернувшихся клиентов в процентах
weekday_stats['return_share'] = (weekday_stats['return_users'] / weekday_stats['total_users']) * 100

# %%
#Проверяю результат
weekday_stats
# Out:
#            total_users  return_users  return_share
# weekday
# Friday            3073          1763     57.370648
# Monday            2721          1641     60.308710
# Saturday          3010          1775     58.970100
# Sunday            2560          1452     56.718750
# Thursday          2954          1693     57.312119
# Tuesday           2941          1729     58.789527
# Wednesday         2874          1718     59.777314

# %%
# Выведу только нужные для анализа колонки
weekday_stats[['total_users', 'return_share']]
# Out:
#            total_users  return_share
# weekday
# Friday            3073     57.370648
# Monday            2721     60.308710
# Saturday          3010     58.970100
# Sunday            2560     56.718750
# Thursday          2954     57.312119
# Tuesday           2941     58.789527
# Wednesday         2874     59.777314

# %%
#Легче всего сравнивать категории с помощью столбцевого графика 
#Сначала построю барный график для подсчета количества клиентов за каждый день недели
plt.figure(figsize=(10,6))


plt.bar(x=weekday_stats.index, height=weekday_stats['total_users'], edgecolor='black')

plt.title('Количество пользователей по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество клиентов')
plt.grid(True)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Friday'),
#   Text(1, 0, 'Monday'),
#   Text(2, 0, 'Saturday'),
#   Text(3, 0, 'Sunday'),
#   Text(4, 0, 'Thursday'),
#   Text(5, 0, 'Tuesday'),
#   Text(6, 0, 'Wednesday')])

# %%
#Теперь построю барный график для отображения доли вернувшихся клиентов

plt.bar(x=weekday_stats.index, height=weekday_stats['return_share'], edgecolor='black')

plt.title('Доля клиентов, совершивших повторные заказы в зависимости от дня недели')
plt.xlabel('День недели')
plt.ylabel('Процент вернувшихся пользователей')
plt.grid(True)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Friday'),
#   Text(1, 0, 'Monday'),
#   Text(2, 0, 'Saturday'),
#   Text(3, 0, 'Sunday'),
#   Text(4, 0, 'Thursday'),
#   Text(5, 0, 'Tuesday'),
#   Text(6, 0, 'Wednesday')])

# %% [markdown]
# #### Промежуточный итог по заданию 4.3.1
# - По результатам анализа было выявлено, что день недели, в которую была совершенна первая покупка, никак не влияет на возможность возврата клиента на сервис
# - Каждый день недели имеет почти одинаковые показатели количества клиентов и процент возврата

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Когда планируют досуг, но возвращаемость остаётся примерно одинаковой — это говорит о том, что день недели первой покупки не влияет на лояльность, а повторное использование сервиса определяется скорее качеством опыта и интересом к мероприятиям

# %% [markdown]
# ---
#
# **Задача 4.3.2.** Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %%
#Выведу названия колонок
user.columns.to_list()
# Out:
# ['order_dt_min',
#  'order_dt_max',
#  'device_type_canonical_first',
#  'region_name_first',
#  'service_name_first',
#  'event_type_main_first',
#  'order_id_count',
#  'revenue_rub_mean',
#  'tickets_count_mean',
#  'avg_days_between_orders_',
#  'is_two_',
#  'is_five_',
#  'avg_revenue_rub',
#  'weekday']

# %%
#Выделим 2 группы клиентов с помощью масок

#Группа пользователей, совершивших 2-4 заказа
group_2_4 = user[(user['order_id_count'] >= 2) & (user['order_id_count'] <= 4)]

#И группа пользлвателей, совершивших 5+ заказов
group_5plus = user[user['order_id_count'] >= 5]

# %%
#Посчитаем количество пользователей в каждой группе
print(len(group_2_4))

print(len(group_5plus))
# Out:
# 6531
# 5240

# %%
#Смотрю есть ли выбросы
group_2_4['avg_days_between_orders_'].describe()
# Out:
# count    6531.000000
# mean       14.725897
# std        17.848351
# min         0.000000
# 25%         0.000000
# 50%         6.000000
# 75%        27.000000
# max        64.000000
# Name: avg_days_between_orders_, dtype: float64

# %%
group_5plus['avg_days_between_orders_'].describe()
# Out:
# count    5240.000000
# mean       11.204167
# std         7.818339
# min         0.000000
# 25%         5.615385
# 50%         9.607692
# 75%        15.500000
# max        37.500000
# Name: avg_days_between_orders_, dtype: float64

# %%
#Посчитаем средний интервал между заказами для этих групп
#Можно посчитать и медиану, т.к. она менее восприимчива к выьросам
avg_2_4 = group_2_4['avg_days_between_orders_'].mean()
median_2_4 = group_2_4['avg_days_between_orders_'].median()


avg_5plus = group_5plus['avg_days_between_orders_'].mean()
median_5plus = group_5plus['avg_days_between_orders_'].median()

# %%
#Проверяю результат
print("Средний интервал между заказами вднях:")
print(f"Для группы с 2-4 заказами среднее:{round(avg_2_4, 2)}, медиана: {median_2_4}")
print(f"Для группы с 5 и более заказами среднее:{round(avg_5plus, 2)}, медиана: {median_5plus}")
# Out:
# Средний интервал между заказами вднях:
# Для группы с 2-4 заказами среднее:14.73, медиана: 6.0
# Для группы с 5 и более заказами среднее:11.2, медиана: 9.607692307692307

# %% [markdown]
# #### Промежуточный итог по заданию 4.3.2
# - Для анализа среднего времени между заказами, я разделил пользователей, корорые делали повторные заказы, на 2 группы по количеству заказов. 1 группа (2-4 заказа) и 2 группа (5 и более заказов)
# - С помощью медианы, я выяснил, что у группы клиентов с меньшим количеством заказов среднее время между заказами меньше, причем существенно.
# - Можно сделать вывод, что чем меньше количество дней между заказов, тем больше вероятность возвращения клиента

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Обрати, пожалуйста, внимание, что в таблице профилей около 20к пользователей. А тут в расчётах около 11к ![image.png](attachment:image.png)

# %% [markdown]
# <b>Не совсем понял, мы ведь сравниваем только 2 группы из 3, группа пользователей с 1 заказом просто не входит в эту выборку</b>

# %%
#Вывожу длинну групп с несколькими заказами
print(len(group_2_4))
print(len(group_5plus))
# Out:
# 6531
# 5240

# %%
#Формирую группу пользователей с 1 заказом
group_1_order = user[user['order_id_count'] == 1]

# %%
#Вывожу длинну группы пользователей с 1 заказом
print(len(group_1_order))
# Out:
# 8362

# %%
#Вывожу общую длинну сгруппированного датасета
print(len(group_1_order) + len(group_2_4) + len(group_5plus))
# Out:
# 20133

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Учтено

# %% [markdown]
# ---
#
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя
#
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# ---
#
# **Задача 4.4.1:** Проведите корреляционный анализ:
# - Рассчитайте коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используйте параметр `interval_cols` для определения интервальных данных.
# - Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю `total_orders`, а затем повторите корреляционный анализ. Выделите такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируйте результат корреляции с помощью тепловой карты.
# - Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?
#
# ---

# %%
#Устанавливаю библиотеку через пакетный менеджер
# !pip install phik

# %%
#Импортирую библиотеку
import phik

# %%
#Сначала удалю лишнюю колонку со средней ценой билета
user = user.drop(columns=['avg_revenue_rub'])

#Также удаляю колонку с днем недели
user = user.drop(columns='weekday')

# %%
#Создаем матрицу корреляций

phik_corr = user.phik_matrix()
# Out:
# interval columns not set, guessing: ['order_id_count', 'revenue_rub_mean', 'tickets_count_mean', 'avg_days_between_orders_']

# %%
#Назначаю колонки, которые просят
correlations = user.phik_matrix(interval_cols=[
    'order_id_count', 
    'revenue_rub_mean', 
    'tickets_count_mean', 
    'avg_days_between_orders_'
])

# %%
#Смотрим результат
correlations
# Out:
#                              order_dt_min  order_dt_max  \
# order_dt_min                     1.000000      0.998993
# order_dt_max                     0.998993      1.000000
# device_type_canonical_first      0.104849      0.088363
# region_name_first                0.472631      0.363466
# service_name_first               0.298901      0.233447
# event_type_main_first            0.259658      0.166022
# order_id_count                   0.423278      0.411373
# revenue_rub_mean                 0.216432      0.240533
# tickets_count_mean               0.238526      0.255924
# avg_days_between_orders_         0.442800      0.278706
# is_two_                          0.359886      0.413761
# is_five_                         0.492957      0.512168
#
#                              device_type_canonical_first  region_name_first  \
# order_dt_min                                    0.104849           0.472631
# order_dt_max                                    0.088363           0.363466
# ...

# %%
#Вывожу корреляцию только для колонки заказов
correlations_with_orders = correlations['order_id_count'].sort_values(ascending=False)
correlations_with_orders
# Out:
# order_id_count                 1.000000
# is_five_                       0.986020
# is_two_                        0.751787
# avg_days_between_orders_       0.634668
# tickets_count_mean             0.427135
# order_dt_min                   0.423278
# order_dt_max                   0.411373
# revenue_rub_mean               0.273189
# device_type_canonical_first    0.050903
# service_name_first             0.044176
# region_name_first              0.033822
# event_type_main_first          0.030941
# Name: order_id_count, dtype: float64

# %%
#Визуализирую phik-матрицу корреляций с помощью тепловой карты
plt.figure(figsize=(12,10))

sns.heatmap(correlations, annot=True, fmt=".2f")
plt.title('Тепловая карта корреляций phik')
plt.xticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5]),
#  [Text(0.5, 0, 'order_dt_min'),
#   Text(1.5, 0, 'order_dt_max'),
#   Text(2.5, 0, 'device_type_canonical_first'),
#   Text(3.5, 0, 'region_name_first'),
#   Text(4.5, 0, 'service_name_first'),
#   Text(5.5, 0, 'event_type_main_first'),
#   Text(6.5, 0, 'order_id_count'),
#   Text(7.5, 0, 'revenue_rub_mean'),
#   Text(8.5, 0, 'tickets_count_mean'),
#   Text(9.5, 0, 'avg_days_between_orders_'),
#   Text(10.5, 0, 'is_two_'),
#   Text(11.5, 0, 'is_five_')])

# %%
# Вывозу сегменты пользователей по количеству заказов total_orders (у мня order_id_count)
# Создаём сегменты
#Пользователи с 1 заказом
segment1 = user[user['order_id_count'] == 1]

#Пользователи с 2 до 4 заказов
segment2 = user[(user['order_id_count'] >= 2) & (user['order_id_count'] <= 4)]

#Пользователи с 5 и более заказми
segment3 = user[user['order_id_count'] >= 5]

# %%
#Считаю количество пользователей в каждом сегменте
print(f"Размер первого сегмента: {len(segment1)}, Размер второго сегмента: {len(segment2)}, Размер третьего сегмента: {len(segment3)}")
# Out:
# Размер первого сегмента: 8362, Размер второго сегмента: 6531, Размер третьего сегмента: 5240

# %%
#Считаем корреляцию внутри каждого сегмента
interval_cols = ['order_id_count', 'revenue_rub_mean', 'tickets_count_mean', 'avg_days_between_orders_']

corr_segment1 = segment1.phik_matrix(interval_cols=interval_cols)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/phik/data_quality.py:72: UserWarning: Not enough unique value for variable order_id_count for analysis 1. Dropping this column
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/phik/data_quality.py:72: UserWarning: Not enough unique value for variable avg_days_between_orders_ for analysis 0. Dropping this column
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/phik/data_quality.py:82: UserWarning: Not enough unique value for variable is_five_ for analysis 1. Dropping this column
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/phik/data_quality.py:82: UserWarning: Not enough unique value for variable is_two_ for analysis 1. Dropping this column
#   warnings.warn(

# %%
#Смотрим на корреляцию для профилей пользователей у которых 1 заказ
corr_segment1
# Out:
#                              order_dt_min  order_dt_max  \
# order_dt_min                     1.000000      1.000000
# order_dt_max                     1.000000      1.000000
# device_type_canonical_first      0.107769      0.107769
# region_name_first                0.415761      0.415761
# service_name_first               0.308346      0.308346
# event_type_main_first            0.263671      0.263671
# revenue_rub_mean                 0.176958      0.176958
# tickets_count_mean               0.099731      0.099731
#
#                              device_type_canonical_first  region_name_first  \
# order_dt_min                                    0.107769           0.415761
# order_dt_max                                    0.107769           0.415761
# device_type_canonical_first                     1.000000           0.095228
# region_name_first                               0.095228           1.000000
# service_name_first                              0.072339           0.667924
# ...

# %% [markdown]
# У первого сегмента пользователей самая большая корреляция с region_name_first

# %%
#Визуализируем корреляцию для пользователей с 1 заказом
#Визуализирую phik-матрицу корреляций с помощью тепловой карты
plt.figure(figsize=(12,10))

sns.heatmap(corr_segment1, annot=True, fmt=".2f")
plt.title('Тепловая карта корреляций для первого сегмента пользователей')
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]),
#  [Text(0.5, 0, 'order_dt_min'),
#   Text(1.5, 0, 'order_dt_max'),
#   Text(2.5, 0, 'device_type_canonical_first'),
#   Text(3.5, 0, 'region_name_first'),
#   Text(4.5, 0, 'service_name_first'),
#   Text(5.5, 0, 'event_type_main_first'),
#   Text(6.5, 0, 'revenue_rub_mean'),
#   Text(7.5, 0, 'tickets_count_mean')])

# %%
#Создадим корреляционную матрицу для второго сегмента клиентов
corr_segment2 = segment2.phik_matrix(interval_cols=interval_cols)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/phik/data_quality.py:82: UserWarning: Not enough unique value for variable is_five_ for analysis 1. Dropping this column
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/phik/data_quality.py:82: UserWarning: Not enough unique value for variable is_two_ for analysis 1. Dropping this column
#   warnings.warn(

# %%
#Смотрим на корреляцию
corr_segment2
# Out:
#                              order_dt_min  order_dt_max  \
# order_dt_min                     1.000000      0.993827
# order_dt_max                     0.993827      1.000000
# device_type_canonical_first      0.093816      0.066968
# region_name_first                0.400565      0.000000
# service_name_first               0.307721      0.301089
# event_type_main_first            0.197026      0.000000
# order_id_count                   0.344251      0.228962
# revenue_rub_mean                 0.133958      0.210257
# tickets_count_mean               0.094849      0.164144
# avg_days_between_orders_         0.517156      0.203539
#
#                              device_type_canonical_first  region_name_first  \
# order_dt_min                                    0.093816           0.400565
# order_dt_max                                    0.066968           0.000000
# device_type_canonical_first                     1.000000           0.100919
# ...

# %% [markdown]
# У order_id_count самая большая корреляция с order_dt_min и avg_days_between_orders

# %%
#Визуализируем корреляцию для 2 сегмента пользователей
plt.figure(figsize=(12,10))

sns.heatmap(corr_segment2, annot=True, fmt=".2f")
plt.title('Тепловая карта корреляций для второго сегмента пользователей')
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  [Text(0.5, 0, 'order_dt_min'),
#   Text(1.5, 0, 'order_dt_max'),
#   Text(2.5, 0, 'device_type_canonical_first'),
#   Text(3.5, 0, 'region_name_first'),
#   Text(4.5, 0, 'service_name_first'),
#   Text(5.5, 0, 'event_type_main_first'),
#   Text(6.5, 0, 'order_id_count'),
#   Text(7.5, 0, 'revenue_rub_mean'),
#   Text(8.5, 0, 'tickets_count_mean'),
#   Text(9.5, 0, 'avg_days_between_orders_')])

# %%
#Создаем корреляционную матрицу для 3-го сегмента пользователей
corr_segment3 = segment3.phik_matrix(interval_cols=interval_cols)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/phik/data_quality.py:82: UserWarning: Not enough unique value for variable is_five_ for analysis 1. Dropping this column
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/phik/data_quality.py:82: UserWarning: Not enough unique value for variable is_two_ for analysis 1. Dropping this column
#   warnings.warn(

# %%
#Смотрим на корреляцию
corr_segment3
# Out:
#                              order_dt_min  order_dt_max  \
# order_dt_min                     1.000000      0.533812
# order_dt_max                     0.533812      1.000000
# device_type_canonical_first      0.074663      0.066122
# region_name_first                0.625247      0.000000
# service_name_first               0.389588      0.000000
# event_type_main_first            0.389184      0.181295
# order_id_count                   0.191701      0.071755
# revenue_rub_mean                 0.339325      0.521488
# tickets_count_mean               0.401541      0.437981
# avg_days_between_orders_         0.558210      0.303317
#
#                              device_type_canonical_first  region_name_first  \
# order_dt_min                                    0.074663           0.625247
# order_dt_max                                    0.066122           0.000000
# device_type_canonical_first                     1.000000           0.139714
# ...

# %% [markdown]
# Самая сильная корреляция у 3-его сегмента пользователей с полем avg_days_between_orders_

# %%
#Визуализируем корреляцию для 3 сегмента пользователей
plt.figure(figsize=(12,10))

sns.heatmap(corr_segment3, annot=True, fmt=".2f")
plt.title('Тепловая карта корреляций для третьего сегмента пользователей')
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  [Text(0.5, 0, 'order_dt_min'),
#   Text(1.5, 0, 'order_dt_max'),
#   Text(2.5, 0, 'device_type_canonical_first'),
#   Text(3.5, 0, 'region_name_first'),
#   Text(4.5, 0, 'service_name_first'),
#   Text(5.5, 0, 'event_type_main_first'),
#   Text(6.5, 0, 'order_id_count'),
#   Text(7.5, 0, 'revenue_rub_mean'),
#   Text(8.5, 0, 'tickets_count_mean'),
#   Text(9.5, 0, 'avg_days_between_orders_')])

# %% [markdown]
# #### Промежуточный итог по заданию 4.3.3
# - Если говорить про сегменты с несколькими заказами, в обоих сегментах лидирует поле avg_days_between_orders (для сегмента 2-4 заказов показатель 0.33, а для сегмента 5 и более заказов корреляция достигает показателя 0.72)
# - Второй по силе признак это tickets_count_mean (Для сегмента 2-4 заказов показатель 0.21, а для сегмента 5 и более заказов показатель равен 0.20)
# - Соответственно среднее время между заказами и количество проданных билетов являются самыми решающими факторами для возврата пользователя
# - Регион, тип устройства, тип события, сервис почти не воияют на число заказов

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С этим заданием тоже справились!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
#
#
# * В выводах Было бы неплохо сделать более явный акцент на том, что поведение клиентов во времени и количество билетов важнее для объяснения повторных покупок, чем их демография или первый выбор сервиса.
#
# </div>
#
# </div>

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**:
#     - Был предоставлен датасет от Яндекс Афиши, который включал в себя информацию о клиентах, их активности, выручке с заказов. Информация была собрана за 5 месяцев наблюдений.
#
#     - Были перерасчитаны значения выручки из тенге в рубли, был отфильтрован набор данных так, чтобы аномально большие единичные значения не искажали результат анализа.
#
#     - Был создан портрет пользователя и посчиталны статистические показатели, также были посчитаны корреляции разных параметров, чтобы лучше понимать как повлиять на желание человека возвращаться на платформу.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Всего выборка насчитывает 21.847 пользователей. Легче всего их было сегментировать на 3 группы (1 заказ, от 2-4 заказов и 5 и более заказов)
#     - Есть положительная связь между количеством купленных билетов и выручкой с вероятностью того, что клиент вернется, однако эта связь слабая.
#     - Чем меньше интервалы времени между заказами, тем больше вероятность того, что клиент вернется, это самая сильная корреляция в этом датафрейме
#     - Средняя выручка больше у клиентов, которые постоянно покупают (имеют среднее число заказов 5 и более)
#     - Можно отметить, что регион, тип устройства, тип события, сервис,через который покупался билет почти не влияют на возможность пользователя вернуться
#
#
# Рекомендация: По итогу проделанной работы, могу сделать рекомендацию о том, что нужно сокращать интервалы времени между покупками, надо стимулировать пользователя постоянно возвращаться за счет событий, акций, скидок. Увеличение количества продаваемых билетов тоже помогает, но гораздо в меньшей степени.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Рекоменадции сейчас немного общие. Понятно, что нужно работать над этим. Можно и без анализа предложить " нужно сокращать интервалы времени между покупками, надо стимулировать пользователя постоянно возвращаться за счет событий, акций, скидок."    Всё же рекомендую более таргетно, на основе полученных данных предлагать рекомендации

# %% [markdown]
# <b>Новая рекомендация:</b>
#
# По итогу проделанной работы, могу сделать рекомендацию о том, что нужно сокращать интервалы времени между покупками, надо стимулировать пользователя постоянно возвращаться за счет событий, акций, скидок - это очевидно.
#
# Мы выяснили, что самый маленький интервал времени между заказами у пользователей, которые делали по (2-3 или 3-5 заказов), то есть небольшие компании или семьи - самые лояльные пользователи сервиса.  Я бы рекомендовал сделать упор на групповые преждложения (например: "Закажи 2 билета, получи 3-ий в подарок" или "проход вне очереди для семей с детьми", это будет побуждать небольшие компании возвращаться на сервис чаще.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# С задачей справились! Все ключевые моменты отражены, что позволяет быстро ознакомиться с процессом работы и результатом, не вдаваясь в технический детали. Здорово, что завершаешь проект рекомендациями, основанные на выявленных закономерностях. Предложенные рекомендации логично следуют из анализа и могут быть непосредственно реализованы в маркетинговых стратегиях подогревания и удержания.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, но в таком случае обязательно нужно засекретить чувствительные данные для принятия проекта

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# <b>Все заполнил по инструкции</b>
# https://github.com/denisenkovv/practicum.project2modul

# %% [markdown]
# Но .env файл не видно, спрятал его в .gitignore

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# Важно убрать чувствительные данные (логины, пароли).
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
#
# Можно еще добавить информацию в readme.md, где указать ключевые моменты проекта. Или зафиксировать цели и полученные выводы.

# %%
##Сделано
